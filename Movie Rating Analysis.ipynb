# %%
import pandas as pd

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\LENOVO'

# %%
movies = pd.read_csv(r'C:\Users\LENOVO\Desktop\Full stack data science class\28th - Movie and Iris set Analysis\29th\MOVIE RATINGS _ ADVANCE VISUALIZATION _ EDA 1/Movie-Rating.csv')

# %%
movies
# Out:
#                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# 1                    44                 105             2008
# ...

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
len(movies.columns)
# Out:
# 6

# %%
movies.shape
# Out:
# (559, 6)

# %%
movies.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movies.tail()
# Out:
#                 Film     Genre  Rotten Tomatoes Ratings %  Audience Ratings %  \
# 554    Your Highness    Comedy                         26                  36
# 555  Youth in Revolt    Comedy                         68                  52
# 556           Zodiac  Thriller                         89                  73
# 557      Zombieland     Action                         90                  87
# 558        Zookeeper    Comedy                         14                  42
#
#      Budget (million $)  Year of release
# 554                  50             2011
# 555                  18             2009
# 556                  65             2007
# 557                  24             2009
# 558                  80             2011

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Film                       559 non-null    object
#  1   Genre                      559 non-null    object
#  2   Rotten Tomatoes Ratings %  559 non-null    int64
#  3   Audience Ratings %         559 non-null    int64
#  4   Budget (million $)         559 non-null    int64
#  5   Year of release            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.columns = ['Film', 'Genre', 'CriticRating', 'AudienceRatings',
       'Budgetmillion', 'Year']
movies.columns
# Out:
# Index(['Film', 'Genre', 'CriticRating', 'AudienceRatings', 'Budgetmillion',
#        'Year'],
#       dtype='object')

# %%
movies.Film = movies.Film.astype('category')
movies.Genre = movies.Genre.astype('category')
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Film             559 non-null    category
#  1   Genre            559 non-null    category
#  2   CriticRating     559 non-null    int64
#  3   AudienceRatings  559 non-null    int64
#  4   Budgetmillion    559 non-null    int64
#  5   Year             559 non-null    int64
# dtypes: category(2), int64(4)
# memory usage: 40.1 KB

# %%
movies
# Out:
#                       Film      Genre  CriticRating  AudienceRatings  \
# 0    (500) Days of Summer      Comedy            87               81
# 1              10,000 B.C.  Adventure             9               44
# 2               12 Rounds      Action            30               52
# 3                127 Hours  Adventure            93               84
# 4                17 Again      Comedy            55               70
# ..                     ...        ...           ...              ...
# 554          Your Highness     Comedy            26               36
# 555        Youth in Revolt     Comedy            68               52
# 556                 Zodiac   Thriller            89               73
# 557            Zombieland      Action            90               87
# 558              Zookeeper     Comedy            14               42
#
#      Budgetmillion  Year
# 0                8  2009
# 1              105  2008
# 2               20  2009
# 3               18  2010
# ...

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRatings  Budgetmillion         Year
# count    559.000000       559.000000     559.000000   559.000000
# mean      47.309481        58.744186      50.236136  2009.152057
# std       26.413091        16.826887      48.731817     1.362632
# min        0.000000         0.000000       0.000000  2007.000000
# 25%       25.000000        47.000000      20.000000  2008.000000
# 50%       46.000000        58.000000      35.000000  2009.000000
# 75%       70.000000        72.000000      65.000000  2010.000000
# max       97.000000        96.000000     300.000000  2011.000000

# %%
movies.Year
# Out:
# 0      2009
# 1      2008
# 2      2009
# 3      2010
# 4      2009
#        ...
# 554    2011
# 555    2009
# 556    2007
# 557    2009
# 558    2011
# Name: Year, Length: 559, dtype: int64

# %%
movies.Year = movies.Year.astype('category')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Film             559 non-null    category
#  1   Genre            559 non-null    category
#  2   CriticRating     559 non-null    int64
#  3   AudienceRatings  559 non-null    int64
#  4   Budgetmillion    559 non-null    int64
#  5   Year             559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 36.5 KB

# %%
movies.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRatings  Budgetmillion
# count    559.000000       559.000000     559.000000
# mean      47.309481        58.744186      50.236136
# std       26.413091        16.826887      48.731817
# min        0.000000         0.000000       0.000000
# 25%       25.000000        47.000000      20.000000
# 50%       46.000000        58.000000      35.000000
# 75%       70.000000        72.000000      65.000000
# max       97.000000        96.000000     300.000000

# %%
#working with joint plot

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
j = sns.jointplot(data = movies, x= 'CriticRating', y= 'AudienceRatings')

# %%
j = sns.jointplot(data= movies, x= 'CriticRating' ,y='AudienceRatings',kind ="hex")

# %%
j = sns.jointplot(data = movies,x='CriticRating',y = 'AudienceRatings', kind='reg')

# %%
m1 = sns.distplot(movies.AudienceRatings)

# %%
sns.set_style('darkgrid')

# %%
m2 = sns.distplot(movies.AudienceRatings, bins=15)

# %%
n1 = plt.hist(movies.AudienceRatings , bins=15)

# %%
sns.set_style('white')
n1 = plt.hist(movies.AudienceRatings,bins=20)

# %%
n1 = plt.hist(movies.CriticRating, bins=20)

# %%
plt.hist(movies.Budgetmillion)
plt.show()

# %%
plt.hist(movies[movies.Genre == 'Drama'].Budgetmillion)
plt.show()

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRatings  \
# 0  (500) Days of Summer      Comedy            87               81
# 1            10,000 B.C.  Adventure             9               44
# 2             12 Rounds      Action            30               52
# 3              127 Hours  Adventure            93               84
# 4              17 Again      Comedy            55               70
#
#    Budgetmillion  Year
# 0              8  2009
# 1            105  2008
# 2             20  2009
# 3             18  2010
# 4             20  2009

# %%
plt.hist(movies[movies.Genre== 'Action'].Budgetmillion,bins=20)
plt.hist(movies[movies.Genre== 'Adventure'].Budgetmillion,bins=20)
plt.hist(movies[movies.Genre== 'Comedy'].Budgetmillion,bins=20)
plt.hist(movies[movies.Genre== 'Thriller'].Budgetmillion,bins=20)
plt.hist(movies[movies.Genre== 'Drama'].Budgetmillion,bins=20)
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.hist([movies[movies.Genre== 'Action'].Budgetmillion,\
          movies[movies.Genre== 'Adventure'].Budgetmillion,\
          movies[movies.Genre== 'Comedy'].Budgetmillion,\
          movies[movies.Genre== 'Thriller'].Budgetmillion,\
          movies[movies.Genre== 'Drama'].Budgetmillion],bins = 20,stacked = True)

plt.show()

# %%
for gen in movies.Genre.cat.categories:
    print(gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
vis1 =sns.lmplot(data = movies,x='CriticRating',y='AudienceRatings', fit_reg = False )

# %%
vis1 = sns.lmplot(data = movies,x='CriticRating',y='AudienceRatings',\
                  fit_reg = False, hue = 'Genre')

# %%
sns.set_style('dark',{'axes.facecolor':'black'})
vis1 = sns.lmplot(data = movies,x='CriticRating',y='AudienceRatings',\
                  fit_reg = False,hue = 'Genre', height = 10, aspect = 1)

# %%
#Kernal Density Estimate plot ( KDE PLOT)

# %%
sns.set_style('white')
k1 = sns.kdeplot(data = movies,x='CriticRating',y='AudienceRatings')

# %%
k1 = sns.kdeplot(data = movies,x='CriticRating',y='AudienceRatings',shade = True,shade_lowest =False,cmap='Reds')

# %%
k2 = sns.kdeplot(data=movies,x='CriticRating',y='AudienceRatings',shade_lowest=False,cmap='Greens_r')

# %%
sns.set_style('dark')
k1= sns.kdeplot(data = movies,x='Budgetmillion',y='AudienceRatings',shade_lowest = False, cmap = 'Greens_r')

# %%
sns.set_style('dark')
k1 = sns.kdeplot(data =movies,x= 'Budgetmillion', y= 'AudienceRatings')

# %%
sns.set_style
k1 = sns.kdeplot(data=movies,x='Budgetmillion',y='CriticRating')

# %%
#subplot

# %%
f,ax =plt.subplots(1,2, figsize=(12,6))

# %%
f, axes = plt.subplots(1,2, figsize =(12,6))
k1 = sns.kdeplot(data = movies,x='Budgetmillion',y='AudienceRatings', ax=axes[0])
k2 = sns.kdeplot(data = movies,x='Budgetmillion',y='CriticRating', ax=axes[1])

# %%
#box plot

# %%
w =sns.boxplot(data = movies, x = 'Genre',y = 'CriticRating')

# %%
#violin plot

# %%
v = sns.violinplot(data=movies, x = 'Genre', y='CriticRating')

# %%
w1 = sns.violinplot(data = movies[movies.Genre=='Drama'], x='Year', y = 'CriticRating')

# %%
w2 = sns.boxplot(data= movies[movies.Genre=='Drama'], x='Year', y = 'CriticRating')

# %%
#Facet grid

# %%
g = sns.FacetGrid(movies,row = 'Genre',col ='Year',hue = 'Genre')

# %%
plt.scatter(movies.CriticRating,movies.AudienceRatings)

# %%
g =sns.FacetGrid (movies, row = 'Genre', col = 'Year', hue = 'Genre')
g = g.map(plt.scatter, 'CriticRating', 'AudienceRatings' )

# %%
sns.set_style('white',{'axes.facecolor':'white'})
g =sns.FacetGrid (movies, row = 'Genre', col = 'Year', hue = 'Genre')
g = g.map(plt.hist,'Budgetmillion')

# %%
g = sns.FacetGrid(movies, row ='Genre', col ='Year', hue = 'Genre')
kws = dict(s=50, linewidth=0.5,edgecolor='black')
g = g.map(plt.scatter,'CriticRating', 'AudienceRatings',**kws)

# %%
sns.set_style('darkgrid')

# %%
f, axes = plt.subplots (2,2, figsize = (20,20))

k1 = sns.kdeplot(data = movies ,x='Budgetmillion',y='AudienceRatings', ax=axes[0,0])
k2 = sns.kdeplot(data = movies ,x='Budgetmillion',y='CriticRating', ax=axes[0,1])



z = sns.violinplot(data=movies[movies.Genre=='Drama'], x='Year', y='CriticRating', ax = axes[1,0])
k2 = sns.kdeplot(data= movies,x= 'CriticRating', y='AudienceRatings',shade = True, \
                 shade_lowest= False,cmap = 'Reds',ax=axes[1,1])
k2a = sns.kdeplot(data =movies,x='CriticRating', y='AudienceRatings',cmap='Reds',ax = axes[1,1])

plt.show()

# %%
sns.set_style('dark',{'axes.facecolor':'black'})
f, axes = plt.subplots (2,2, figsize = (15,15))

k1 = sns.kdeplot(data= movies, x='Budgetmillion',y='AudienceRatings',shade = True, shade_lowest= True,\
                 cmap='inferno',ax=axes[0,0] )
k1a = sns.kdeplot(data= movies, x='Budgetmillion',y='AudienceRatings',cmap='cool',ax=axes[0,0] )

k2 = sns.kdeplot(data= movies, x='Budgetmillion',y='CriticRating',shade = True, shade_lowest= True,\
                 cmap='cool',ax=axes[0,1])
k2b = sns.kdeplot(data= movies, x='Budgetmillion',y='CriticRating',cmap='cool',ax=axes[0,1])


z = sns.violinplot(data=movies[movies.Genre=='Drama'],x='Year',y='CriticRating', ax=axes[1,0])

k3= sns.kdeplot(data =movies, x= 'CriticRating', y='AudienceRatings',shade = True, shade_lowest= True,\
                cmap='Blues_r',ax = axes[1,1])

k3a = sns.kdeplot(data =movies, x= 'CriticRating', y='AudienceRatings', cmap='gist_gray_r',ax = axes[1,1])
                 


plt.show()
